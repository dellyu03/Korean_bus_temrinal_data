# %%
import csv
import requests
from bs4 import BeautifulSoup
import re

# %%
base_url = 'https://transportation.asamaru.net/'

# %% [markdown]
# ## 지역 이름(개수) 가져오기 테스트

# %%
regions = [
    "seoulteugbyeolsi",
    "kyeongkido",
    "incheonkwangyeogsi",
    "daejeonkwangyeogsi",
    "daekukwangyeogsi",
    "ulsankwangyeogsi",
    "busankwangyeogsi",
    "kwangjukwangyeogsi",
    "sejongteugbyeoljachisi",
    "kangwonteugbyeoljachido",
    "chungcheongbugdo",
    "chungcheongnamdo",
    "kyeongsangbugdo",
    "kyeongsangnamdo",
    "jeonbugteugbyeoljachido",
    "jeonlanamdo",
    "jejuteugbyeoljachido",
]

# %% [markdown]
# ## Step1. 전체 html 가져오기

# %%
response = requests.get(base_url+'시외버스/터미널')

if response.status_code == 200:
    html = response.text
    soup = BeautifulSoup(html, 'html.parser')

# %% [markdown]
# ## Step2. Extract Province

# %%
provinces = []
for region in regions:
    province, province_num = (soup.find('h2', id = f"toc-{region}").text).split(" ")
    province_data = (province, int(province_num.strip('(').strip(')')))
    provinces.append(province_data)
    
provinces
# Out:
# [('서울특별시', 9),
#  ('경기도', 101),
#  ('인천광역시', 3),
#  ('대전광역시', 12),
#  ('대구광역시', 8),
#  ('울산광역시', 10),
#  ('부산광역시', 26),
#  ('광주광역시', 8),
#  ('세종특별자치시', 4),
#  ('강원특별자치도', 97),
#  ('충청북도', 43),
#  ('충청남도', 59),
#  ('경상북도', 58),
#  ('경상남도', 77),
#  ('전북특별자치도', 47),
#  ('전라남도', 92),
#  ('제주특별자치도', 0)]

# %% [markdown]
# ## Step3. Extract city

# %%
cities = []

for tag in soup.find_all('h3'):
    city_temp = tag.get_text(strip = True)
    city_name, city_num = city_temp.split("(")

    city = (city_name, int(city_num.strip(')')))
    cities.append(city)

cities
# Out:
# [('강서구', 1),
#  ('광진구', 1),
#  ('서초구', 3),
#  ('송파구', 3),
#  ('중랑구', 1),
#  ('가평군', 3),
#  ('고양시 일산동구', 1),
#  ('광명시', 2),
#  ('광주시', 1),
#  ('구리시', 1),
#  ('군포시', 2),
#  ('부천시 원미구', 1),
#  ('성남시 분당구', 1),
#  ('수원시 권선구', 2),
#  ('수원시 영통구', 2),
#  ('수원시 팔달구', 3),
#  ('시흥시', 1),
#  ('안산시 상록구', 1),
#  ('안성시', 10),
#  ('안양시 동안구', 4),
#  ('안양시 만안구', 3),
#  ('양평군', 2),
#  ('여주시', 3),
#  ('오산시', 12),
#  ('용인시 기흥구', 6),
#  ('용인시 수지구', 1),
#  ('용인시 처인구', 5),
#  ('의왕시', 3),
#  ('의정부시', 6),
#  ('이천시', 6),
#  ('평택시', 8),
#  ('포천시', 8),
#  ('하남시', 1),
#  ('화성시', 2),
#  ('미추홀구', 1),
#  ('중구', 2),
#  ('대덕구', 1),
#  ('동구', 2),
#  ('서구', 3),
#  ('유성구', 4),
#  ('중구', 2),
#  ('군위군', 1),
#  ('남구', 1),
#  ('달성군', 1),
#  ('동구', 3),
#  ('서구', 2),
#  ('남구', 6),
#  ('북구', 3),
#  ('울주군', 1),
#  ('강서구', 1),
#  ('금정구', 1),
#  ('기장군', 4),
#  ('동구', 1),
#  ('동래구', 1),
#  ('부산진구', 2),
#  ('사상구', 2),
#  ('사하구', 1),
#  ('수영구', 1),
#  ('연제구', 1),
#  ('해운대구', 11),
#  ('광산구', 2),
#  ('남구', 1),
#  ('동구', 2),
#  ('북구', 2),
#  ('서구', 1),
#  ('세종특별자치시', 4),
#  ('강릉시', 6),
#  ('고성군', 3),
#  ('동해시', 1),
#  ('삼척시', 6),
#  ('속초시', 3),
#  ('양구군', 3),
#  ('양양군', 8),
#  ('영월군', 1),
#  ('원주시', 3),
#  ('인제군', 5),
#  ('정선군', 7),
#  ('철원군', 3),
#  ('춘천시', 23),
#  ('태백시', 1),
#  ('평창군', 9),
#  ('홍천군', 3),
#  ('화천군', 9),
#  ('횡성군', 3),
#  ('괴산군', 1),
#  ('단양군', 6),
#  ('보은군', 2),
#  ('영동군', 3),
#  ('옥천군', 1),
#  ('음성군', 6),
#  ('제천시', 1),
#  ('증평군', 1),
#  ('진천군', 3),
#  ('청주시 상당구', 1),
#  ('청주시 서원구', 2),
#  ('청주시 청원구', 4),
#  ('청주시 흥덕구', 3),
#  ('충주시', 9),
#  ('계룡시', 3),
#  ('공주시', 5),
#  ('금산군', 3),
#  ('논산시', 3),
#  ('당진시', 6),
#  ('보령시', 1),
#  ('부여군', 2),
#  ('서산시', 8),
#  ('서천군', 2),
#  ('아산시', 6),
#  ('예산군', 5),
#  ('천안시 동남구', 2),
#  ('천안시 서북구', 2),
#  ('청양군', 3),
#  ('태안군', 5),
#  ('홍성군', 3),
#  ('경산시', 4),
#  ('경주시', 3),
#  ('고령군', 1),
#  ('구미시', 3),
#  ('김천시', 3),
#  ('문경시', 2),
#  ('봉화군', 4),
#  ('상주시', 4),
#  ('성주군', 1),
#  ('안동시', 7),
#  ('영덕군', 3),
#  ('영양군', 2),
#  ('영주시', 2),
#  ('영천시', 2),
#  ('예천군', 3),
#  ('울진군', 7),
#  ('의성군', 2),
#  ('청송군', 4),
#  ('포항시 남구', 1),
#  ('거제시', 5),
#  ('거창군', 2),
#  ('고성군', 2),
#  ('김해시', 3),
#  ('남해군', 2),
#  ('밀양시', 1),
#  ('사천시', 6),
#  ('산청군', 5),
#  ('양산시', 1),
#  ('의령군', 6),
#  ('진주시', 6),
#  ('창녕군', 5),
#  ('창원시 마산합포구', 1),
#  ('창원시 마산회원구', 2),
#  ('창원시 성산구', 2),
#  ('창원시 의창구', 2),
#  ('창원시 진해구', 3),
#  ('통영시', 1),
#  ('하동군', 6),
#  ('함안군', 4),
#  ('함양군', 6),
#  ('합천군', 6),
#  ('고창군', 3),
#  ('군산시', 2),
#  ('김제시', 1),
#  ('남원시', 4),
#  ('무주군', 4),
#  ('부안군', 1),
#  ('순창군', 1),
#  ('완주군', 8),
#  ('익산시', 6),
#  ('임실군', 1),
#  ('장수군', 2),
#  ('전주시 덕진구', 4),
#  ('전주시 완산구', 5),
#  ('정읍시', 3),
#  ('진안군', 2),
#  ('강진군', 3),
#  ('고흥군', 9),
#  ('곡성군', 3),
#  ('광양시', 4),
#  ('구례군', 2),
#  ('나주시', 3),
#  ('담양군', 2),
#  ('목포시', 1),
#  ('무안군', 5),
#  ('보성군', 9),
#  ('순천시', 6),
#  ('신안군', 2),
#  ('여수시', 3),
#  ('영광군', 3),
#  ('영암군', 4),
#  ('완도군', 5),
#  ('장성군', 7),
#  ('장흥군', 7),
#  ('진도군', 4),
#  ('함평군', 2),
#  ('해남군', 7),
#  ('화순군', 1)]

# %% [markdown]
# ## Step4. Extract Terminals

# %%
terminals = []

terminals = []

terminals = []

for region in regions:
    div_tag = soup.find('div', attrs={'data-scrollspy-content': region})
    if not div_tag:
        continue

    spans = div_tag.select('.ft-area-terminal span.pe-2')
    terminals.extend([span.get_text(strip=True) for span in spans])

terminals
# Out:
# ['김포공항정류소',
#  '동서울종합터미널',
#  '서울고속버스터미널(경부 영동선)',
#  '서울남부터미널',
#  '센트럴시티터미널(호남선)',
#  '잠실역정류소',
#  '잠실역중앙정류소',
#  '장지역시외버스정류소',
#  '상봉시외버스터미널',
#  '가평터미널',
#  '대성리정류소',
#  '청평터미널',
#  '고양종합터미널',
#  '광명종합터미널',
#  '광명철산역정류소',
#  '경기도광주종합터미널',
#  '구리시외버스정류장',
#  '군포산본터미널',
#  '군포시외버스정류소',
#  '부천터미널소풍',
#  '성남종합버스터미널',
#  '서수원버스터미널',
#  '수원버스터미널',
#  '경제과학진흥원',
#  '아주대병원',
#  '아주대정류소',
#  '우만동터미널',
#  '창현고.유신고',
#  '시흥종합버스터미널',
#  '안산버스터미널',
#  '공도시외버스정류장',
#  '동아방송대정류소',
#  '두원대정류소',
#  '안성대림동산정류소',
#  '안성종합버스터미널',
#  '안성회관정류소',
#  '일죽버스터미널',
#  '죽산시외버스터미널',
#  '중앙대',
#  '풍림아파트(안성)',
#  '범계역정류소',
#  '의왕내손동',
#  '인덕원역',
#  '호계시외버스정류소',
#  '관악역정류소',
#  '안양시외버스정류장 하행',
#  '안양역시외버스정류장',
#  '양평버스터미널',
#  '용문버스터미널',
#  '가남태평버스정류소',
#  '여주대정류소',
#  '여주종합터미널',
#  '교육지원청사거리(오산)',
#  '세교2지구7단지',
#  '세교고인돌공원',
#  '세교한신더휴',
#  '세마역정류장',
#  '오산대역후문',
#  '오산시청',
#  '오산역환승센터',
#  '오산초등학교',
#  '운암주공1단지',
#  '운암주공5단지',
#  '호반써밋라포레(오산)',
#  '강남대역',
#  '신갈영덕시외버스정류장',
#  '신갈용인정류소',
#  '영통입구(인천방면)',
#  '영통입구정류소',
#  '용인기흥역시외버스정류소',
#  '죽전(경전)',
#  '명지대',
#  '에버랜드',
#  '용인공용버스터미널',
#  '용인대',
#  '용인정류소',
#  '고천시외버스정류장',
#  '의왕TG',
#  '의왕고천',
#  '만가대사거리',
#  '의정부시외버스터미널',
#  '의정부역정류장',
#  '이마트의정부점',
#  '청구아파트(민락동)',
#  '푸른마당근린공원',
#  '아미리정류소',
#  '오천(이천시)',
#  '오천리더웰아파트정류장',
#  '이천종합터미널',
#  '이황리정류소',
#  '장호원정류소',
#  '송탄시외버스터미널',
#  '숙성리정류소',
#  '안중버스터미널',
#  '안중오거리정류소',
#  '태평아파트',
#  '평택대정류소',
#  '평택시외버스터미널',
#  '평택호',
#  '대진대정류소',
#  '송우리정류소',
#  '신북정류소',
#  '양문정류소',
#  '운천정류소',
#  '이동정류소',
#  '일동버스터미널',
#  '포천시외버스터미널',
#  '하남시버스환승공영차고지',
#  '동탄역',
#  '향남환승터미널',
#  '인천종합터미널',
#  '인천공항T1정류장',
#  '인천공항T2정류장',
#  '신탄진역정류장',
#  '대전복합터미널',
#  '대전신흥정류장',
#  '관저건양대병원시외버스정류소',
#  '대전청사시외버스둔산정류소(승차)',
#  '도마동시외버스정류소',
#  '대전도룡동정류소',
#  '북대전IC시외버스정류소',
#  '유성복합터미널',
#  '자운대정류소',
#  '대전서남부터미널',
#  '부사동정류장',
#  '군위버스터미널',
#  '대구서부정류장',
#  '현풍공영버스정류장',
#  '대구공항정류소',
#  '대구용계정류소',
#  '동대구터미널',
#  '대구북부시외버스터미널',
#  '서대구역',
#  '공업탑시외버스정류장',
#  '울산고속버스터미널',
#  '울산공업탑',
#  '울산법원앞',
#  '울산시외버스터미널',
#  '울산신복정류소',
#  '울산공항정류소',
#  '호계시외버스정류장',
#  '효문정류소',
#  '언양임시시외버스터미널',
#  '김해공항정류소',
#  '부산종합버스터미널',
#  '동암후문(아난티코프)',
#  '반얀트리해운대부산',
#  '오시리아테마파크',
#  '좌천정류소',
#  '부산역',
#  '부산동래시외버스정류소',
#  '동의대역',
#  '서면(부산)',
#  '부산서부사상버스터미널',
#  '주례역',
#  '부산신평정류소',
#  '상수도남부사업소',
#  '부산(하단)',
#  '경남마리나아파트',
#  '부산해운대시외버스정류소',
#  '센텀호텔',
#  '신세계백화점',
#  '장산역',
#  '조선비치호텔',
#  '파라다이스호텔',
#  '파크하얏트호텔',
#  '한화리조트',
#  '해운대수도권시외버스정류장',
#  '해운대해수욕장(공항)',
#  '송정역시외버스정류장(광주 광산구)',
#  '우산동(하남)시외버스정류장',
#  '진월동시외버스정류장',
#  '소태터미널',
#  '학동시외버스정류장',
#  '문화동시외버스정류소',
#  '운암동시외버스정류소',
#  '광주종합버스터미널(유.스퀘어)',
#  '세종고속시외버스터미널',
#  '세종청사정류소(하행)',
#  '정부세종청사정류장',
#  '조치원버스터미널',
#  '강릉시외버스터미널',
#  '고단',
#  '삽당령',
#  '송현리(강릉시)',
#  '왕산(강릉시)',
#  '주문진시외버스종합터미널',
#  '간성터미널',
#  '거진시외버스터미널',
#  '대진시외버스터미널',
#  '동해시종합버스터미널',
#  '도계버스터미널(삼척)',
#  '삼척종합버스정류장',
#  '삼척해변정류장',
#  '임원버스정류소',
#  '장호정류장',
#  '호산버스정류장',
#  '물치정류소',
#  '속초고속버스터미널',
#  '속초시외버스터미널',
#  '대월',
#  '양구시외버스터미널',
#  '양구정중앙터미널',
#  '낙산버스터미널',
#  '남애',
#  '손양',
#  '양양국제공항',
#  '양양종합여객터미널',
#  '오색버스터미널',
#  '인구',
#  '하조대정류소',
#  '영월시외버스정류장',
#  '귀래정류소',
#  '문막버스정류소',
#  '원주시외버스터미널',
#  '백담사입구정류소',
#  '신남정류장',
#  '원통버스터미널',
#  '인제터미널',
#  '현리시외버스터미널',
#  '고한사북공영버스터미널',
#  '나전(정선)',
#  '신동(정선)',
#  '여량',
#  '임계시외버스터미널',
#  '정선공영버스터미널',
#  '하늘공원',
#  '동송시외버스공용터미널',
#  '신철원터미널',
#  '와수터미널',
#  '강촌버스승강장',
#  '군단앞(춘천)',
#  '남면(추곡)',
#  '당림리',
#  '동부아파트(춘천)',
#  '두미르아파트정류장',
#  '발산리정류장',
#  '사북면사',
#  '상호아파트',
#  '서천1리',
#  '서천2리',
#  '소양로배터',
#  '신포중학교',
#  '안보리',
#  '어리고개정류장',
#  '원평리',
#  '전력IT단지',
#  '지촌정류소',
#  '춘천시외버스터미널',
#  '춘천역',
#  '한샘고등학교',
#  '현대아파트(춘천)',
#  '현지사',
#  '태백버스터미널',
#  '미탄정류소',
#  '방림',
#  '방림삼거리정류소',
#  '운교정류소',
#  '장평시외버스터미널',
#  '진부시외버스터미널',
#  '평창버스터미널',
#  '평창휴게소',
#  '횡계시외버스터미널',
#  '내면정류소',
#  '양덕원정류소',
#  '홍천종합버스터미널',
#  '간척',
#  '간척사거리',
#  '다목리버스터미널',
#  '달거리',
#  '사창리버스터미널',
#  '서오지리',
#  '용호리(유촌리)',
#  '원천정류소',
#  '화천공영버스터미널',
#  '새말시외버스정류장',
#  '안흥정류소(횡성군)',
#  '횡성시외버스터미널',
#  '괴산시외버스터미널',
#  '구인사정류소',
#  '단양상진터미널',
#  '단양시외버스공영터미널',
#  '매포정류소',
#  '사평리',
#  '영춘공동정류소',
#  '보은시외버스공용정류장',
#  '속리산터미널',
#  '(구)영동',
#  '영동(시장)',
#  '영동시외버스정류장',
#  '옥천시외버스공영정류소',
#  '감곡공용정류장',
#  '금왕임시정류소',
#  '대소버스정류장',
#  '삼성버스터미널',
#  '음성공용버스터미널',
#  '충북혁신도시공용터미널',
#  '제천버스터미널',
#  '증평시외버스터미널',
#  '광혜원터미널',
#  '덕산진천정류소',
#  '진천종합터미널',
#  '미원정류소 상행',
#  '남부정류장',
#  '사창정류장',
#  '율량정류소',
#  '청주공항정류소',
#  '청주대정류소',
#  '청주북부터미널(오창)',
#  '오송역',
#  '오송역(오스코)',
#  '청주시외버스터미널',
#  '건국터미널',
#  '교통대시외버스정류소',
#  '목계정류소',
#  '목행',
#  '본리정류소',
#  '수안보시외버스정류소',
#  '엄정정류소',
#  '주덕버스터미널',
#  '충주공용버스터미널',
#  '계룡(금암)정류소',
#  '신도안정류소',
#  '엄사정류소',
#  '공주종합버스터미널',
#  '광정정류소',
#  '동학사삼거리정류소',
#  '삼흥고속',
#  '유구터미널',
#  '금산터미널',
#  '인삼랜드휴게소(통영방향)고속버스환승정류소',
#  '인삼랜드휴게소(하남방향)고속버스환승정류소',
#  '논산버스터미널',
#  '연무대시외버스정류장',
#  '황화',
#  '기지시버스정류장',
#  '당진버스터미널',
#  '삽교천시외버스터미널',
#  '송악신도시',
#  '신평고속버스정류장',
#  '합덕버스터미널',
#  '보령종합터미널',
#  '부여시외버스터미널',
#  '한국전통문화대',
#  '고북정류소',
#  '대산(서산시)',
#  '서산공용버스터미널',
#  '성연정류장',
#  '운산정류소',
#  '음암정류소',
#  '한서대정류소',
#  '해미정류소',
#  '서천버스정류장',
#  '장항버스정류장',
#  '밀두리',
#  '배방환승정류장',
#  '신창정류소',
#  '아산서부봉강교정류소',
#  '아산시외버스터미널',
#  '천안아산역KTX정류소',
#  '내포신도시고속시외버스정류소',
#  '신례원정류소',
#  '신양정류소',
#  '예산종합터미널',
#  '임성동',
#  '천안시외버스터미널',
#  '코리아텍정류장',
#  '성환버스터미널',
#  '쌍용동정류장',
#  '운곡정류소',
#  '청양시외버스터미널',
#  '화성정류소',
#  '만리포시외버스정류소',
#  '안면도버스정류소',
#  '창기리정류소',
#  '태안공영버스터미널',
#  '태안남면정류소',
#  '갈산(홍성군)',
#  '광천버스터미널',
#  '홍성종합터미널',
#  '경산시외버스정류장',
#  '대구대정류소',
#  '영남대시외버스정류장',
#  '하양정류소',
#  '경주고속터미널',
#  '경주시외버스터미널',
#  '안강동부정류장',
#  '고령시외버스정류장',
#  '구미공단정류소',
#  '구미복지정류소',
#  '구미종합터미널',
#  '김천구미역정류소',
#  '김천부곡공항버스정류장',
#  '김천시외버스정류장',
#  '문경버스터미널',
#  '점촌터미널',
#  '법전정류소',
#  '봉화공용정류장',
#  '상운',
#  '춘양버스터미널',
#  '경북대상주캠퍼스정류소',
#  '상주터미널',
#  '양정정류소(상주시)',
#  '함창버스정류장',
#  '임시성주버스정류장',
#  '경북도청버스정류장',
#  '안동대',
#  '안동초교정류소',
#  '안동터미널',
#  '옹천정류소',
#  '용상정류소',
#  '임동정류소',
#  '강구버스터미널',
#  '영덕터미널',
#  '영해버스터미널',
#  '영양버스정류장',
#  '입암정류장',
#  '영주종합터미널',
#  '풍기IC정류소',
#  '동영천IC정류장',
#  '영천버스터미널',
#  '예천삼거리정류소',
#  '예천시외버스터미널',
#  '용궁정류소',
#  '금강송시외버스정류장',
#  '부구터미널',
#  '온정종합터미널',
#  '울진종합버스터미널',
#  '죽변시외버스정류장',
#  '평해버스정류장',
#  '후포터미널',
#  '도리원버스터미널',
#  '의성시외버스터미널',
#  '안덕버스터미널',
#  '주왕산버스터미널',
#  '진보버스터미널',
#  '청송버스터미널',
#  '포항터미널',
#  '거제(한화오션남문)',
#  '고현버스터미널',
#  '옥포정류소',
#  '장승포시외(능포동)',
#  '장승포시외버스정류장',
#  '가조정류소',
#  '거창버스터미널',
#  '고성여객자동차터미널',
#  '배둔시외버스터미널',
#  '김해여객터미널',
#  '김해장유고속버스환승정류장',
#  '장유시외버스정류소',
#  '남해공용터미널',
#  '남해사거리',
#  '밀양버스터미널',
#  '곤양공용터미널',
#  '사천공항',
#  '사천터미널',
#  '삼천포시외버스터미널',
#  '용현(사천시)',
#  '우주항공청정류장',
#  '덕산(산청)',
#  '산청버스터미널',
#  '생초버스정류장',
#  '원지버스정류소',
#  '중산리(산청)',
#  '양산시외버스터미널',
#  '가례정류장',
#  '대의정류소',
#  '신반정류소',
#  '의령버스터미널',
#  '정암(의령군)',
#  '칠곡(의령)',
#  '경남과학기술대학교정류소',
#  '진주개양시외버스승강장',
#  '진주도동정류소',
#  '진주시외버스터미널',
#  '진주역',
#  '진주혁신도시정류장',
#  '남지버스터미널',
#  '부곡버스터미널',
#  '영산정류소',
#  '이방정류소',
#  '창녕시외버스터미널',
#  '마산남부시외버스터미널',
#  '내서고속버스터미널',
#  '마산시외버스터미널',
#  '남산시외버스정류소',
#  '정우상가',
#  '창원역시외고속버스정류소',
#  '창원종합버스터미널',
#  '용원시외버스센터',
#  '진해경찰서정류소',
#  '진해시외버스터미널',
#  '통영종합버스터미널',
#  '개치',
#  '전도정류소',
#  '진교터미널',
#  '하동(교통쉼터)정류장',
#  '하동버스터미널',
#  '화개버스터미널',
#  '가야주공',
#  '군북버스터미널',
#  '월촌(함안군)',
#  '함안버스터미널',
#  '마천정류소',
#  '백무동시외버스정류소',
#  '서상버스터미널',
#  '수동정류소',
#  '안의버스터미널',
#  '함양시외버스터미널',
#  '대양',
#  '삼가정류소',
#  '쌍백정류장',
#  '적교정류소',
#  '합천버스정류장',
#  '해인사시외버스터미널',
#  '고창문화터미널',
#  '해리공용버스터미널',
#  '흥덕버스터미널',
#  '군산시외버스터미널',
#  '대야공용버스터미널',
#  '김제종합버스터미널',
#  '남원공용버스터미널',
#  '달궁',
#  '반선시외버스터미널',
#  '인월지리산공용터미널',
#  '무주공용버스터미널',
#  '무주리조트',
#  '설천(무주군)',
#  '안성시외버스터미널',
#  '부안터미널',
#  '순창공용버스정류장',
#  '둔산공원',
#  '봉동(완주군)',
#  '삼례공용터미널',
#  '삼봉지구',
#  '완주혁신도시시외버스승강장',
#  '우석대정류소',
#  '익산IC정류장',
#  '장신대정류소',
#  '금마',
#  '여산',
#  '원광대학교앞정류소',
#  '익산시외버스터미널',
#  '익산역정류소',
#  '익산왕궁정류소',
#  '임실공용터미널',
#  '장계시외버스공용터미널',
#  '장수공용버스터미널',
#  '덕진동정류장',
#  '인후동간이정류소',
#  '전주시외버스공용터미널',
#  '호남제일문시외버스정류장',
#  '노송동정류소',
#  '완산동간이정류소',
#  '전주대정류소',
#  '전주리무진터미널',
#  '효자서부시외버스간이정류소',
#  '신태인공영터미널',
#  '정읍고속버스터미널',
#  '정읍시외버스터미널',
#  '우화',
#  '진안시외버스공용정류장',
#  '강진버스여객터미널',
#  '성전터미널',
#  '전남인재개발원정류장',
#  '고흥공용버스정류장',
#  '과역버스터미널',
#  '나로도공용터미널',
#  '남성정류장',
#  '녹동공영버스터미널',
#  '도화(고흥군)',
#  '백양정류장(고흥군)',
#  '소록도',
#  '포두정류장',
#  '곡성버스터미널',
#  '석곡터미널',
#  '옥과터미널',
#  '광양터미널',
#  '광영',
#  '동광양중마버스터미널',
#  '섬진강휴게소(순천방향)고속버스환승정류소',
#  '구례공영버스터미널',
#  '노고단(성삼재)정류소',
#  '나주버스터미널',
#  '빛가람시외버스정류장',
#  '영산포공용터미널',
#  '금성(담양군)',
#  '담양공용버스터미널',
#  '목포종합버스터미널',
#  '남악정류소',
#  '목포대',
#  '무안버스터미널',
#  '청계정류소',
#  '현경정류소',
#  '녹차밭정류소',
#  '문덕버스정류장',
#  '벌교공용버스터미널',
#  '보성버스터미널',
#  '보성북문버스정류장',
#  '복내정류소',
#  '예당정류소',
#  '율포정류소',
#  '조성정류소',
#  '곡천정류소',
#  '광천시외버스터미널',
#  '순천북부정류소',
#  '순천신대지구CGV정류소',
#  '순천역시외버스정류장',
#  '순천종합버스터미널',
#  '우전리욕장',
#  '지도여객자동차터미널',
#  '덕양시외버스터미널',
#  '여수종합버스터미널',
#  '여천시외버스정류장',
#  '법성버스정류장',
#  '영광종합버스터미널',
#  '홍농버스터미널',
#  '독천터미널',
#  '삼호정류소',
#  '신북터미널',
#  '영암여객자동차터미널',
#  '고금시외버스정류장',
#  '당목정류소',
#  '완도공용버스터미널',
#  '원동버스터미널',
#  '해양치유센터(완도)',
#  '내장사(장성)',
#  '사창정류소',
#  '상무대정류소',
#  '상무아파트정류소',
#  '신흥정류소(장성)',
#  '장성공영버스터미널',
#  '장성사거리버스여객터미널',
#  '관산터미널',
#  '대덕버스정류소',
#  '배산정류소',
#  '용산정류소',
#  '장평정류소',
#  '장흥시외버스터미널',
#  '회진시외버스터미널',
#  '녹진',
#  '쏠비치진도정류소',
#  '진도공용터미널',
#  '진도항화물터미널',
#  '문장공영터미널',
#  '함평공영터미널',
#  '남리정류소',
#  '남창시외버스터미널',
#  '땅끝정류소',
#  '산정정류소',
#  '우수영정류소',
#  '월송자동차여객터미널',
#  '해남종합버스터미널',
#  '화순전남대병원']

# %% [markdown]
# ## Step5. Match Terminal to cities

# %%
from collections import deque

terminal_queue = list(terminals)
city_queue = deque(cities)

final_terminal_data = {}

for province_name, province_count in provinces:
    province_dict = {}
    count_so_far = 0

    while count_so_far < province_count and city_queue:
        city_name, city_count = city_queue.popleft()
        province_dict[city_name] = [terminal_queue.pop(0) for _ in range(city_count) if terminal_queue]
        count_so_far += city_count

    final_terminal_data[province_name] = province_dict

final_terminal_data
# Out:
# {'서울특별시': {'강서구': ['김포공항정류소'],
#   '광진구': ['동서울종합터미널'],
#   '서초구': ['서울고속버스터미널(경부 영동선)', '서울남부터미널', '센트럴시티터미널(호남선)'],
#   '송파구': ['잠실역정류소', '잠실역중앙정류소', '장지역시외버스정류소'],
#   '중랑구': ['상봉시외버스터미널']},
#  '경기도': {'가평군': ['가평터미널', '대성리정류소', '청평터미널'],
#   '고양시 일산동구': ['고양종합터미널'],
#   '광명시': ['광명종합터미널', '광명철산역정류소'],
#   '광주시': ['경기도광주종합터미널'],
#   '구리시': ['구리시외버스정류장'],
#   '군포시': ['군포산본터미널', '군포시외버스정류소'],
#   '부천시 원미구': ['부천터미널소풍'],
#   '성남시 분당구': ['성남종합버스터미널'],
#   '수원시 권선구': ['서수원버스터미널', '수원버스터미널'],
#   '수원시 영통구': ['경제과학진흥원', '아주대병원'],
#   '수원시 팔달구': ['아주대정류소', '우만동터미널', '창현고.유신고'],
#   '시흥시': ['시흥종합버스터미널'],
#   '안산시 상록구': ['안산버스터미널'],
#   '안성시': ['공도시외버스정류장',
#    '동아방송대정류소',
#    '두원대정류소',
#    '안성대림동산정류소',
#    '안성종합버스터미널',
#    '안성회관정류소',
#    '일죽버스터미널',
#    '죽산시외버스터미널',
#    '중앙대',
#    '풍림아파트(안성)'],
#   '안양시 동안구': ['범계역정류소', '의왕내손동', '인덕원역', '호계시외버스정류소'],
#   '안양시 만안구': ['관악역정류소', '안양시외버스정류장 하행', '안양역시외버스정류장'],
#   '양평군': ['양평버스터미널', '용문버스터미널'],
#   '여주시': ['가남태평버스정류소', '여주대정류소', '여주종합터미널'],
#   '오산시': ['교육지원청사거리(오산)',
#    '세교2지구7단지',
#    '세교고인돌공원',
#    '세교한신더휴',
#    '세마역정류장',
#    '오산대역후문',
#    '오산시청',
#    '오산역환승센터',
#    '오산초등학교',
#    '운암주공1단지',
#    '운암주공5단지',
#    '호반써밋라포레(오산)'],
#   '용인시 기흥구': ['강남대역',
#    '신갈영덕시외버스정류장',
#    '신갈용인정류소',
#    '영통입구(인천방면)',
#    '영통입구정류소',
#    '용인기흥역시외버스정류소'],
#   '용인시 수지구': ['죽전(경전)'],
#   '용인시 처인구': ['명지대', '에버랜드', '용인공용버스터미널', '용인대', '용인정류소'],
#   '의왕시': ['고천시외버스정류장', '의왕TG', '의왕고천'],
#   '의정부시': ['만가대사거리',
#    '의정부시외버스터미널',
#    '의정부역정류장',
#    '이마트의정부점',
#    '청구아파트(민락동)',
#    '푸른마당근린공원'],
#   '이천시': ['아미리정류소', '오천(이천시)', '오천리더웰아파트정류장', '이천종합터미널', '이황리정류소', '장호원정류소'],
#   '평택시': ['송탄시외버스터미널',
#    '숙성리정류소',
#    '안중버스터미널',
#    '안중오거리정류소',
#    '태평아파트',
#    '평택대정류소',
#    '평택시외버스터미널',
#    '평택호'],
#   '포천시': ['대진대정류소',
#    '송우리정류소',
#    '신북정류소',
#    '양문정류소',
#    '운천정류소',
#    '이동정류소',
#    '일동버스터미널',
#    '포천시외버스터미널'],
#   '하남시': ['하남시버스환승공영차고지'],
#   '화성시': ['동탄역', '향남환승터미널']},
#  '인천광역시': {'미추홀구': ['인천종합터미널'], '중구': ['인천공항T1정류장', '인천공항T2정류장']},
#  '대전광역시': {'대덕구': ['신탄진역정류장'],
#   '동구': ['대전복합터미널', '대전신흥정류장'],
#   '서구': ['관저건양대병원시외버스정류소', '대전청사시외버스둔산정류소(승차)', '도마동시외버스정류소'],
#   '유성구': ['대전도룡동정류소', '북대전IC시외버스정류소', '유성복합터미널', '자운대정류소'],
#   '중구': ['대전서남부터미널', '부사동정류장']},
#  '대구광역시': {'군위군': ['군위버스터미널'],
#   '남구': ['대구서부정류장'],
#   '달성군': ['현풍공영버스정류장'],
#   '동구': ['대구공항정류소', '대구용계정류소', '동대구터미널'],
#   '서구': ['대구북부시외버스터미널', '서대구역']},
#  '울산광역시': {'남구': ['공업탑시외버스정류장',
#    '울산고속버스터미널',
#    '울산공업탑',
#    '울산법원앞',
#    '울산시외버스터미널',
#    '울산신복정류소'],
#   '북구': ['울산공항정류소', '호계시외버스정류장', '효문정류소'],
#   '울주군': ['언양임시시외버스터미널']},
#  '부산광역시': {'강서구': ['김해공항정류소'],
#   '금정구': ['부산종합버스터미널'],
#   '기장군': ['동암후문(아난티코프)', '반얀트리해운대부산', '오시리아테마파크', '좌천정류소'],
#   '동구': ['부산역'],
#   '동래구': ['부산동래시외버스정류소'],
#   '부산진구': ['동의대역', '서면(부산)'],
#   '사상구': ['부산서부사상버스터미널', '주례역'],
#   '사하구': ['부산신평정류소'],
#   '수영구': ['상수도남부사업소'],
#   '연제구': ['부산(하단)'],
#   '해운대구': ['경남마리나아파트',
#    '부산해운대시외버스정류소',
#    '센텀호텔',
#    '신세계백화점',
#    '장산역',
#    '조선비치호텔',
#    '파라다이스호텔',
#    '파크하얏트호텔',
#    '한화리조트',
#    '해운대수도권시외버스정류장',
#    '해운대해수욕장(공항)']},
#  '광주광역시': {'광산구': ['송정역시외버스정류장(광주 광산구)', '우산동(하남)시외버스정류장'],
#   '남구': ['진월동시외버스정류장'],
#   '동구': ['소태터미널', '학동시외버스정류장'],
#   '북구': ['문화동시외버스정류소', '운암동시외버스정류소'],
#   '서구': ['광주종합버스터미널(유.스퀘어)']},
#  '세종특별자치시': {'세종특별자치시': ['세종고속시외버스터미널',
#    '세종청사정류소(하행)',
#    '정부세종청사정류장',
#    '조치원버스터미널']},
#  '강원특별자치도': {'강릉시': ['강릉시외버스터미널',
#    '고단',
#    '삽당령',
#    '송현리(강릉시)',
#    '왕산(강릉시)',
#    '주문진시외버스종합터미널'],
#   '고성군': ['간성터미널', '거진시외버스터미널', '대진시외버스터미널'],
#   '동해시': ['동해시종합버스터미널'],
#   '삼척시': ['도계버스터미널(삼척)',
#    '삼척종합버스정류장',
#    '삼척해변정류장',
#    '임원버스정류소',
#    '장호정류장',
#    '호산버스정류장'],
#   '속초시': ['물치정류소', '속초고속버스터미널', '속초시외버스터미널'],
#   '양구군': ['대월', '양구시외버스터미널', '양구정중앙터미널'],
#   '양양군': ['낙산버스터미널',
#    '남애',
#    '손양',
#    '양양국제공항',
#    '양양종합여객터미널',
#    '오색버스터미널',
#    '인구',
#    '하조대정류소'],
#   '영월군': ['영월시외버스정류장'],
#   '원주시': ['귀래정류소', '문막버스정류소', '원주시외버스터미널'],
#   '인제군': ['백담사입구정류소', '신남정류장', '원통버스터미널', '인제터미널', '현리시외버스터미널'],
#   '정선군': ['고한사북공영버스터미널',
#    '나전(정선)',
#    '신동(정선)',
#    '여량',
#    '임계시외버스터미널',
#    '정선공영버스터미널',
#    '하늘공원'],
#   '철원군': ['동송시외버스공용터미널', '신철원터미널', '와수터미널'],
#   '춘천시': ['강촌버스승강장',
#    '군단앞(춘천)',
#    '남면(추곡)',
#    '당림리',
#    '동부아파트(춘천)',
#    '두미르아파트정류장',
#    '발산리정류장',
#    '사북면사',
#    '상호아파트',
#    '서천1리',
#    '서천2리',
#    '소양로배터',
#    '신포중학교',
#    '안보리',
#    '어리고개정류장',
#    '원평리',
#    '전력IT단지',
#    '지촌정류소',
#    '춘천시외버스터미널',
#    '춘천역',
#    '한샘고등학교',
#    '현대아파트(춘천)',
#    '현지사'],
#   '태백시': ['태백버스터미널'],
#   '평창군': ['미탄정류소',
#    '방림',
#    '방림삼거리정류소',
#    '운교정류소',
#    '장평시외버스터미널',
#    '진부시외버스터미널',
#    '평창버스터미널',
#    '평창휴게소',
#    '횡계시외버스터미널'],
#   '홍천군': ['내면정류소', '양덕원정류소', '홍천종합버스터미널'],
#   '화천군': ['간척',
#    '간척사거리',
#    '다목리버스터미널',
#    '달거리',
#    '사창리버스터미널',
#    '서오지리',
#    '용호리(유촌리)',
#    '원천정류소',
#    '화천공영버스터미널'],
#   '횡성군': ['새말시외버스정류장', '안흥정류소(횡성군)', '횡성시외버스터미널']},
#  '충청북도': {'괴산군': ['괴산시외버스터미널'],
#   '단양군': ['구인사정류소', '단양상진터미널', '단양시외버스공영터미널', '매포정류소', '사평리', '영춘공동정류소'],
#   '보은군': ['보은시외버스공용정류장', '속리산터미널'],
#   '영동군': ['(구)영동', '영동(시장)', '영동시외버스정류장'],
#   '옥천군': ['옥천시외버스공영정류소'],
#   '음성군': ['감곡공용정류장',
#    '금왕임시정류소',
#    '대소버스정류장',
#    '삼성버스터미널',
#    '음성공용버스터미널',
#    '충북혁신도시공용터미널'],
#   '제천시': ['제천버스터미널'],
#   '증평군': ['증평시외버스터미널'],
#   '진천군': ['광혜원터미널', '덕산진천정류소', '진천종합터미널'],
#   '청주시 상당구': ['미원정류소 상행'],
#   '청주시 서원구': ['남부정류장', '사창정류장'],
#   '청주시 청원구': ['율량정류소', '청주공항정류소', '청주대정류소', '청주북부터미널(오창)'],
#   '청주시 흥덕구': ['오송역', '오송역(오스코)', '청주시외버스터미널'],
#   '충주시': ['건국터미널',
#    '교통대시외버스정류소',
#    '목계정류소',
#    '목행',
#    '본리정류소',
#    '수안보시외버스정류소',
#    '엄정정류소',
#    '주덕버스터미널',
#    '충주공용버스터미널']},
#  '충청남도': {'계룡시': ['계룡(금암)정류소', '신도안정류소', '엄사정류소'],
#   '공주시': ['공주종합버스터미널', '광정정류소', '동학사삼거리정류소', '삼흥고속', '유구터미널'],
#   '금산군': ['금산터미널', '인삼랜드휴게소(통영방향)고속버스환승정류소', '인삼랜드휴게소(하남방향)고속버스환승정류소'],
#   '논산시': ['논산버스터미널', '연무대시외버스정류장', '황화'],
#   '당진시': ['기지시버스정류장',
#    '당진버스터미널',
#    '삽교천시외버스터미널',
#    '송악신도시',
#    '신평고속버스정류장',
#    '합덕버스터미널'],
#   '보령시': ['보령종합터미널'],
#   '부여군': ['부여시외버스터미널', '한국전통문화대'],
#   '서산시': ['고북정류소',
#    '대산(서산시)',
#    '서산공용버스터미널',
#    '성연정류장',
#    '운산정류소',
#    '음암정류소',
#    '한서대정류소',
#    '해미정류소'],
#   '서천군': ['서천버스정류장', '장항버스정류장'],
#   '아산시': ['밀두리', '배방환승정류장', '신창정류소', '아산서부봉강교정류소', '아산시외버스터미널', '천안아산역KTX정류소'],
#   '예산군': ['내포신도시고속시외버스정류소', '신례원정류소', '신양정류소', '예산종합터미널', '임성동'],
#   '천안시 동남구': ['천안시외버스터미널', '코리아텍정류장'],
#   '천안시 서북구': ['성환버스터미널', '쌍용동정류장'],
#   '청양군': ['운곡정류소', '청양시외버스터미널', '화성정류소'],
#   '태안군': ['만리포시외버스정류소', '안면도버스정류소', '창기리정류소', '태안공영버스터미널', '태안남면정류소'],
#   '홍성군': ['갈산(홍성군)', '광천버스터미널', '홍성종합터미널']},
#  '경상북도': {'경산시': ['경산시외버스정류장', '대구대정류소', '영남대시외버스정류장', '하양정류소'],
#   '경주시': ['경주고속터미널', '경주시외버스터미널', '안강동부정류장'],
#   '고령군': ['고령시외버스정류장'],
#   '구미시': ['구미공단정류소', '구미복지정류소', '구미종합터미널'],
#   '김천시': ['김천구미역정류소', '김천부곡공항버스정류장', '김천시외버스정류장'],
#   '문경시': ['문경버스터미널', '점촌터미널'],
#   '봉화군': ['법전정류소', '봉화공용정류장', '상운', '춘양버스터미널'],
#   '상주시': ['경북대상주캠퍼스정류소', '상주터미널', '양정정류소(상주시)', '함창버스정류장'],
#   '성주군': ['임시성주버스정류장'],
#   '안동시': ['경북도청버스정류장', '안동대', '안동초교정류소', '안동터미널', '옹천정류소', '용상정류소', '임동정류소'],
#   '영덕군': ['강구버스터미널', '영덕터미널', '영해버스터미널'],
#   '영양군': ['영양버스정류장', '입암정류장'],
#   '영주시': ['영주종합터미널', '풍기IC정류소'],
#   '영천시': ['동영천IC정류장', '영천버스터미널'],
#   '예천군': ['예천삼거리정류소', '예천시외버스터미널', '용궁정류소'],
#   '울진군': ['금강송시외버스정류장',
#    '부구터미널',
#    '온정종합터미널',
#    '울진종합버스터미널',
#    '죽변시외버스정류장',
#    '평해버스정류장',
#    '후포터미널'],
#   '의성군': ['도리원버스터미널', '의성시외버스터미널'],
#   '청송군': ['안덕버스터미널', '주왕산버스터미널', '진보버스터미널', '청송버스터미널'],
#   '포항시 남구': ['포항터미널']},
#  '경상남도': {'거제시': ['거제(한화오션남문)',
#    '고현버스터미널',
#    '옥포정류소',
#    '장승포시외(능포동)',
#    '장승포시외버스정류장'],
#   '거창군': ['가조정류소', '거창버스터미널'],
#   '고성군': ['고성여객자동차터미널', '배둔시외버스터미널'],
#   '김해시': ['김해여객터미널', '김해장유고속버스환승정류장', '장유시외버스정류소'],
#   '남해군': ['남해공용터미널', '남해사거리'],
#   '밀양시': ['밀양버스터미널'],
#   '사천시': ['곤양공용터미널', '사천공항', '사천터미널', '삼천포시외버스터미널', '용현(사천시)', '우주항공청정류장'],
#   '산청군': ['덕산(산청)', '산청버스터미널', '생초버스정류장', '원지버스정류소', '중산리(산청)'],
#   '양산시': ['양산시외버스터미널'],
#   '의령군': ['가례정류장', '대의정류소', '신반정류소', '의령버스터미널', '정암(의령군)', '칠곡(의령)'],
#   '진주시': ['경남과학기술대학교정류소',
#    '진주개양시외버스승강장',
#    '진주도동정류소',
#    '진주시외버스터미널',
#    '진주역',
#    '진주혁신도시정류장'],
#   '창녕군': ['남지버스터미널', '부곡버스터미널', '영산정류소', '이방정류소', '창녕시외버스터미널'],
#   '창원시 마산합포구': ['마산남부시외버스터미널'],
#   '창원시 마산회원구': ['내서고속버스터미널', '마산시외버스터미널'],
#   '창원시 성산구': ['남산시외버스정류소', '정우상가'],
#   '창원시 의창구': ['창원역시외고속버스정류소', '창원종합버스터미널'],
#   '창원시 진해구': ['용원시외버스센터', '진해경찰서정류소', '진해시외버스터미널'],
#   '통영시': ['통영종합버스터미널'],
#   '하동군': ['개치', '전도정류소', '진교터미널', '하동(교통쉼터)정류장', '하동버스터미널', '화개버스터미널'],
#   '함안군': ['가야주공', '군북버스터미널', '월촌(함안군)', '함안버스터미널'],
#   '함양군': ['마천정류소', '백무동시외버스정류소', '서상버스터미널', '수동정류소', '안의버스터미널', '함양시외버스터미널'],
#   '합천군': ['대양', '삼가정류소', '쌍백정류장', '적교정류소', '합천버스정류장', '해인사시외버스터미널']},
#  '전북특별자치도': {'고창군': ['고창문화터미널', '해리공용버스터미널', '흥덕버스터미널'],
#   '군산시': ['군산시외버스터미널', '대야공용버스터미널'],
#   '김제시': ['김제종합버스터미널'],
#   '남원시': ['남원공용버스터미널', '달궁', '반선시외버스터미널', '인월지리산공용터미널'],
#   '무주군': ['무주공용버스터미널', '무주리조트', '설천(무주군)', '안성시외버스터미널'],
#   '부안군': ['부안터미널'],
#   '순창군': ['순창공용버스정류장'],
#   '완주군': ['둔산공원',
#    '봉동(완주군)',
#    '삼례공용터미널',
#    '삼봉지구',
#    '완주혁신도시시외버스승강장',
#    '우석대정류소',
#    '익산IC정류장',
#    '장신대정류소'],
#   '익산시': ['금마', '여산', '원광대학교앞정류소', '익산시외버스터미널', '익산역정류소', '익산왕궁정류소'],
#   '임실군': ['임실공용터미널'],
#   '장수군': ['장계시외버스공용터미널', '장수공용버스터미널'],
#   '전주시 덕진구': ['덕진동정류장', '인후동간이정류소', '전주시외버스공용터미널', '호남제일문시외버스정류장'],
#   '전주시 완산구': ['노송동정류소', '완산동간이정류소', '전주대정류소', '전주리무진터미널', '효자서부시외버스간이정류소'],
#   '정읍시': ['신태인공영터미널', '정읍고속버스터미널', '정읍시외버스터미널'],
#   '진안군': ['우화', '진안시외버스공용정류장']},
#  '전라남도': {'강진군': ['강진버스여객터미널', '성전터미널', '전남인재개발원정류장'],
#   '고흥군': ['고흥공용버스정류장',
#    '과역버스터미널',
#    '나로도공용터미널',
#    '남성정류장',
#    '녹동공영버스터미널',
#    '도화(고흥군)',
#    '백양정류장(고흥군)',
#    '소록도',
#    '포두정류장'],
#   '곡성군': ['곡성버스터미널', '석곡터미널', '옥과터미널'],
#   '광양시': ['광양터미널', '광영', '동광양중마버스터미널', '섬진강휴게소(순천방향)고속버스환승정류소'],
#   '구례군': ['구례공영버스터미널', '노고단(성삼재)정류소'],
#   '나주시': ['나주버스터미널', '빛가람시외버스정류장', '영산포공용터미널'],
#   '담양군': ['금성(담양군)', '담양공용버스터미널'],
#   '목포시': ['목포종합버스터미널'],
#   '무안군': ['남악정류소', '목포대', '무안버스터미널', '청계정류소', '현경정류소'],
#   '보성군': ['녹차밭정류소',
#    '문덕버스정류장',
#    '벌교공용버스터미널',
#    '보성버스터미널',
#    '보성북문버스정류장',
#    '복내정류소',
#    '예당정류소',
#    '율포정류소',
#    '조성정류소'],
#   '순천시': ['곡천정류소',
#    '광천시외버스터미널',
#    '순천북부정류소',
#    '순천신대지구CGV정류소',
#    '순천역시외버스정류장',
#    '순천종합버스터미널'],
#   '신안군': ['우전리욕장', '지도여객자동차터미널'],
#   '여수시': ['덕양시외버스터미널', '여수종합버스터미널', '여천시외버스정류장'],
#   '영광군': ['법성버스정류장', '영광종합버스터미널', '홍농버스터미널'],
#   '영암군': ['독천터미널', '삼호정류소', '신북터미널', '영암여객자동차터미널'],
#   '완도군': ['고금시외버스정류장', '당목정류소', '완도공용버스터미널', '원동버스터미널', '해양치유센터(완도)'],
#   '장성군': ['내장사(장성)',
#    '사창정류소',
#    '상무대정류소',
#    '상무아파트정류소',
#    '신흥정류소(장성)',
#    '장성공영버스터미널',
#    '장성사거리버스여객터미널'],
#   '장흥군': ['관산터미널',
#    '대덕버스정류소',
#    '배산정류소',
#    '용산정류소',
#    '장평정류소',
#    '장흥시외버스터미널',
#    '회진시외버스터미널'],
#   '진도군': ['녹진', '쏠비치진도정류소', '진도공용터미널', '진도항화물터미널'],
#   '함평군': ['문장공영터미널', '함평공영터미널'],
#   '해남군': ['남리정류소',
#    '남창시외버스터미널',
#    '땅끝정류소',
#    '산정정류소',
#    '우수영정류소',
#    '월송자동차여객터미널',
#    '해남종합버스터미널'],
#   '화순군': ['화순전남대병원']},
#  '제주특별자치도': {}}

# %% [markdown]
# ## Step6 Extract to CSV

# %%
import csv

rows = []
for province, cities_dict in final_terminal_data.items():
    for city, terminals_list in cities_dict.items():
        for terminal in terminals_list:
            rows.append((province, city, terminal))

with open('bus_terminals.csv', 'w', newline='', encoding='utf-8-sig') as f:
    writer = csv.writer(f)
    writer.writerow(['province', 'city', 'terminal_name'])
    writer.writerows(rows)

print(f"총 {len(rows)}개 터미널 저장 완료 → bus_terminals.csv")
# Out:
# 총 654개 터미널 저장 완료 → bus_terminals.csv
